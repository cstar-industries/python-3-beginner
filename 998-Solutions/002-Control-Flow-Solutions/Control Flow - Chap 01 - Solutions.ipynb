# %% [markdown]
# <a href="https://colab.research.google.com/github/cstar-industries/python-3-beginner/blob/master/998-Solutions/002-Control-Flow-Solutions/Control Flow - Chap 01 - Solutions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab" /></a>

# %% [markdown]
# ## 1. Comparison operators
#
# The following blocks should all output `True`, but they all have something wrong. Either they output `False` or they trigger an error.
#
# Fix every block by changing only the operator, and output `True`. Try to guess and keep the original intent of the programmer.

# %%
a = 1

print(a == 1)

# %%
a = 'Hello World!'

print(a == 'Hello World!')

# %%
a = 1138
b = 2020

print(a != b)

# %%
a = 2

print(a <= 3)

# %%
vowels = 'aeiou'
print('a' in vowels)

# %% [markdown]
# ## 2. English-to-Python translation
#
# Use Python operators to evaluate the truth of stated in English.
#
# Example:
#
# * Is `x` greater than or equal to 2?
#
# ```python
# x >= 2
# ```
#
# * Is `x` equal to `0` or to `10`?
#
# ```python
# x == 0 or x == 10
# ```

# %%
# Init block. Initializes the variables used in the exercises.
# Run this block once at the beginning
a = 2020
b = 2
s = 'I would walk 500 miles'

# %% [markdown]
# * Is `a` equal to 2013?

# %%
a == 2013

# %% [markdown]
# * Is `b` equal to `a`?

# %%
b == a

# %% [markdown]
# * Is `s` of type `str` ?

# %%
type(s) == str

# %% [markdown]
# * Can the last digit of `a` be found in `s`?

# %%
str(a)[0] in s

# %% [markdown]
# * Is `a` equal to `2018 + b`?

# %%
a == (2018 + b)

# %% [markdown]
# * Is `a` the same object as `2018 + b`?

# %%
a is (2018 + b)
