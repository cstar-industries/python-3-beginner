# %% [markdown]
# <a href="https://colab.research.google.com/github/cstar-industries/python-3-beginner/blob/master/998-Solutions/001-First-Steps-Solutions/First Steps - Chap 03 - Solutions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab" /></a>

# %% [markdown]
# ## 1. Fix the strings
#
# All of the strings in the following block have something wrong. Find a way to fix them, then output all of them.
#
# ```
# I'm learning Python.
# Python is fun!
# All my friends keep telling me: "you should learn Python"
# This is snek...
# hissss hissss
# ```

# %%
learning = "I'm learning Python."
fun = "Python is fun!"
friends = 'All my friends keep telling me: "you should learn Python"'
snek = "This is snek...\nhissss hissss"

print(learning)
print(fun)
print(friends)
print(snek)

# %% [markdown]
# ## 2. String statistics
#
# Ask the user for any amount of text, and output the length of the text, the first letter and the last letter.
#
# ```
# Enter some text: We were somewhere around Barstow on the edge of the desert when the drugs began to take hold.
#
# Text length: 93 characters
# First character: W
# Last character: .
# ```

# %%
s = input('Enter some text: ')

print()
print(f'Text length: {len(s)}')
print(f'First character: {s[0]}')
print(f'Last character: {s[-1]}')

# %% [markdown]
# ## 3. Uppercase/lowercase
#
# Ask the user for a few words as input, and print the words in lowercase, then uppercase.
#
# ```
# Enter a few words: hello
#
# HELLO
# hello
# ```
#
# Try for a number of different words including numbers, symbols and special characters. What happens?

# %%
s = input('Enter a few words: ')

print()
print(s.upper())
print(s.lower())

# %% [markdown]
# ## 4. Split words
#
# The `str` type has `split` method that comes in very handy when processing text.
#
# Try using it on the text in the example text. Then try using it passing different characters as argument, such as `' '`, `'\n'` and others.
#
# > What is the type of the object returned by calling `split`? This type will be most interesting in Python and we will learn more about is very soon.

# %%
# What's this? Three double-quotes denotes a multi-line string. Instead of
# breaking at a new line, the new line is captured in the string. Only a matching
# set of three double-quotes can close the string.
the_stranger = """MOTHER died today. Or, maybe, yesterday; I can’t be sure. The telegram from the
Home says: YOUR MOTHER PASSED AWAY. FUNERAL TOMORROW. DEEP
SYMPATHY. Which leaves the matter doubtful; it could have been yesterday.
The Home for Aged Persons is at Marengo, some fifty miles from Algiers. With
the two o’clock bus I should get there well before nightfall. Then I can spend the
night there, keeping the usual vigil beside the body, and be back here by tomorrow
evening. I have fixed up with my employer for two days’ leave; obviously, under the
circumstances, he couldn’t refuse. Still, I had an idea he looked annoyed, and I said,
without thinking: “Sorry, sir, but it’s not my fault, you know.”"""

print(the_stranger.split())
print(the_stranger.split(' '))
print(the_stranger.split('\n'))
print(the_stranger.split('e'))

# %% [markdown]
# ## 5. Replacing characters in a string
#
# Using the string `the_stranger` from the previous, and the `replace` method on `str`, transform the paragraph into one long line.
#
# The first block is an example of using `replace`. Run it to see how it works, and play with it to understand better.
#
# Next, use the `replace` method on `the_stranger` and print out a one-line version of the multi-line paragraph.

# %%
s = "i thought i saw a pussycat."

s2 = s.replace('i', 'I')
print(s2)

s2 = s2.replace('s', 'th')
print(s2)

s2 = s2.replace('thaw', 'heard')
print(s2)

# %%
print(the_stranger.replace('\n', ' '))
